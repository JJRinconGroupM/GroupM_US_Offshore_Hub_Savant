# %%
import sys
sys.path.append(str('/home/jupyter/'))
sys.path
# Out:
# ['/home/jupyter/eu',
#  '/opt/conda/lib/python310.zip',
#  '/opt/conda/lib/python3.10',
#  '/opt/conda/lib/python3.10/lib-dynload',
#  '',
#  '/opt/conda/lib/python3.10/site-packages',
#  '/home/jupyter/']

# %%
import pandas as pd
from configparser import ConfigParser
from repo.MyConfigParser import MyConfigParser
from repo.Optimization import SavantPSO
# import numpy as np
from repo.LoadData import DataLoader
from repo.BuildModel import GenerateModelFile, CreateModel
from repo.Accuracy import AccuracyCalculator, ProphetParameterSearch, PlotAccuracyCharts
from repo.FileGenerator import *

# %% [markdown]
# # Read In

# %%
updated_config = ConfigParser()
config_in_path = "/home/jupyter/eu/24 Feb Update/config ups eu.ini"
updated_config.read(config_in_path)

getdict = MyConfigParser()
config_dict=getdict.GetDict(updated_config)
region = config_dict['CLIENTINFO']['country']
cutoff_month = config_dict['PROPHETSETTING']['cut_off_point']
base_start = config_dict['PROPHETSETTING']['reference_start_date1']
base_end = config_dict['PROPHETSETTING']['reference_end_date1']
periods = config_dict['PROPHETSETTING']['periods']
base_periods  = config_dict['PROPHETSETTING']['base_periods']

output_bucket = config_dict["FILEPATH"]["output_bucket"]
folder_name = config_dict["FILEPATH"]["folder_name"]

base_path = config_dict["FILEPATH"]["base_path"]

boundary_df_in_path = base_path + config_dict["FILEPATH"]["boundary_df_in_path"]
daily_df_out_path = base_path + config_dict["FILEPATH"]["daily_df_out_path"]
analytical_file_path = base_path + config_dict["FILEPATH"]["analytical_file_path"]
cuts_df_in_path = base_path + config_dict["FILEPATH"]["cuts_df_in_path"]
plot_name = base_path + config_dict["FILEPATH"]["plot_name"]
constraint_file_name = base_path + config_dict["FILEPATH"]["constraint_file_name"]
breakdown_ls = [config_dict['CLIENTINFO'][i] for i in [f'breakdown{i}' for i in range(1,5)] if config_dict['CLIENTINFO'][i] != None]

small_market_str = ''
pre_forecast_period_budget = float(config_dict['CLIENTINFO']['pre_forecast_period_budget'])
client_budget = float(config_dict['CLIENTINFO']['client_budget'])

save_date = config_dict['CLIENTINFO']['save_date']

# %%
# Get forecasters
bdDf = pd.read_csv(cuts_df_in_path)#.drop('Unnamed: 0', axis = 1)
cuts_df = bdDf.reset_index(drop = True)
cuts_df['forecaster_name_list'] =  cuts_df['market'] + ' ' + cuts_df['account_type'] + ' ' + cuts_df['funnel'] + '.pkl' #' 05.19.2021 Final.pkl'
cuts_df['periods'] = periods
# get model list
forecasters_array = cuts_df.forecaster_name_list

# Get analytical file
analytical_file = pd.read_csv(analytical_file_path).drop('Unnamed: 0', axis = 1)
analytical_file['ds'] = pd.to_datetime(analytical_file['ds'])
analytical_file_check_version = analytical_file.copy()

# Get constrain file
constraint_file = pd.read_csv(constraint_file_name)
constraint_file['init'] = constraint_file[['MinWeight', 'MaxWeight']].mean(axis = 1)

# %% [markdown]
# # Functions

# %%
resultPSO = SavantPSO(cuts_df, analytical_file, constraint_file, config_dict)

# %%
# %load_ext autoreload
# %autoreload 2
itNum = 180
options = {'c1': 0.20255337412386598,
 'c2': 0.034812002156869526,
 'w': 0.8707709059066462}
# today = '01.15.2024' #datetime.date.today().strftime("%m.%d.%Y")# 
# fileName = base_path + f'Pos Result {today}.csv' #today
# pos_df = pd.read_csv(fileName).drop('Unnamed: 0', axis = 1)
# inputWeights =np.tile(pos_df.pos.to_numpy(), [1, 1])
result = resultPSO.run_pso(options,  itNum = itNum)
# Out:
# 2024-02-06 03:02:16,774 - pyswarms.single.global_best - INFO - Optimize for 180 iters with {'c1': 0.20255337412386598, 'c2': 0.034812002156869526, 'w': 0.8707709059066462}
# /home/jupyter/eu/24 Feb Update/Input Weight History 02.06.2024.csv
# pyswarms.single.global_best:   0%|          |0/180
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1387507.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1387507.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1387507.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1387507.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1387507.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1387507.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1387507.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1387507.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1387507.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1387507.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1387507.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1387507.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1387507.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1387507.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1387507.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1387507.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1387507.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1387507.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1387507.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1387507.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1387507.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1387507.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1387507.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1387507.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1387507.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1387507.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1387507.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1387507.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1387507.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1387507.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1387507.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# pyswarms.single.global_best:   1%|          |1/180, best_cost=-1.39e+6
# yhat: -1387507.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1393797.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1388995.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1388166.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1396862.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1381781.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1396117.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1386843.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1384395.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1397466.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1398238.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1384854.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1382096.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1388395.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1389378.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1387140.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1381117.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1388960.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1383133.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1375107.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1389864.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1379806.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1397823.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1386809.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1379215.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1385352.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1390180.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1393752.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1391774.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1396128.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1385458.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1387236.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# pyswarms.single.global_best:   1%|          |2/180, best_cost=-1.4e+6
# yhat: -1399881.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1396448.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1390215.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1386811.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1390225.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1394334.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1393353.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1377638.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1398339.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1376482.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1381079.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1386116.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1389514.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1394392.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1379986.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1372362.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1385121.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1382141.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1395402.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1382502.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1382754.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1397001.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1379194.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1388344.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1395167.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1394033.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1380056.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1381486.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1381218.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1381443.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1387762.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1389589.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# pyswarms.single.global_best:   2%|▏         |3/180, best_cost=-1.4e+6
# yhat: -1392319.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1384051.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1380686.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1382245.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1377824.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1397423.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1394861.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1387116.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1385016.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1378773.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1381886.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1381539.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1393616.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1388851.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1388328.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1385623.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1374835.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1392599.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1384306.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1400759.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1395636.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1397677.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1387602.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1388488.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1386434.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1391385.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1395454.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1396867.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1378885.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1396410.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1396095.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1375800.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# pyswarms.single.global_best:   2%|▏         |4/180, best_cost=-1.4e+6
# yhat: -1379241.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1383920.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1390043.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1389826.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1381347.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1389019.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1395038.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1388771.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1393256.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1383243.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1375656.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1391205.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1378265.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1385271.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1392607.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1385155.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1389833.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1385204.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1397617.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1375614.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1389710.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1390485.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1376491.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1382689.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1390797.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1390851.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1386032.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1385975.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1387512.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1386958.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1379055.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1391956.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# pyswarms.single.global_best:   3%|▎         |5/180, best_cost=-1.4e+6
# yhat: -1391405.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1390494.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1390750.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1386026.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1388433.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1385986.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1380561.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1388168.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1388243.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1381719.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1383900.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1363857.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1383159.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1388006.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1381011.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1393869.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1389848.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1395412.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1402695.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1395713.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1379321.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1383252.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1392831.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1390699.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1390945.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1387191.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1385818.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1386608.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1385344.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1383664.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1397406.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1389375.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# pyswarms.single.global_best:   3%|▎         |6/180, best_cost=-1.4e+6
# yhat: -1396452.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1389646.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1400169.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1389883.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1391066.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1377346.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1396933.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1373142.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1382180.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1390625.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# ...
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1402602.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1396083.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1402627.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1398542.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1401067.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1390549.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1391995.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1389301.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1407217.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1407674.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1387579.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1400795.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1391568.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1395888.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1383821.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1385097.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1393051.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1389556.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1409820.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1398173.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1404001.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1408367.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1391074.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1405358.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1385709.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1392647.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1392550.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1405812.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1390259.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1394408.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# pyswarms.single.global_best:  66%|██████▌   |118/180, best_cost=-1.41e+6
# yhat: -1388135.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1400326.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1401224.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1399052.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1407794.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1404334.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1402284.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1386253.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1385650.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1403972.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1402845.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1401649.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1392767.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1405471.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1385733.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1389706.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1384187.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1392462.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1390840.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1390170.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1411969.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1401843.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1408623.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1409141.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1381167.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1405141.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1382376.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1397200.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1393017.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1406289.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1396243.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1401068.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# pyswarms.single.global_best:  66%|██████▌   |119/180, best_cost=-1.41e+6
# yhat: -1382478.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1400931.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1403376.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0
# yhat: -1380792.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  -0.0
# yhat: -1405460.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  6242581.0 difference between planned and forecast X:  0.0

# %%
resultPSO.SaveResult(result)
