# %%
#!pip install pyswarms

# %% [markdown]
# Import packages

# %%
import sys
sys.path.append(str('/home/jupyter/GroupM_US_Offshore_Hub_Savant/All Regions/'))
import pandas as pd
from configparser import ConfigParser
from repo.MyConfigParser import MyConfigParser
from repo.Optimization import SavantPSO
import numpy as np

# %% [markdown]
# # Read In

# %% [markdown]
# Import the config file and set the config dict. set some variables from the config dict

# %%
updated_config = ConfigParser()
config_in_path = "/home/jupyter/GroupM_US_Offshore_Hub_Savant/All Regions/ca/1 June Update/config ups ca.ini"
updated_config.read(config_in_path)

getdict = MyConfigParser()
config_dict=getdict.GetDict(updated_config)
region = config_dict['CLIENTINFO']['country']
cutoff_month = config_dict['PROPHETSETTING']['cut_off_point']
base_start = config_dict['PROPHETSETTING']['reference_start_date1']
base_end = config_dict['PROPHETSETTING']['reference_end_date1']
periods = config_dict['PROPHETSETTING']['periods']
base_periods  = config_dict['PROPHETSETTING']['base_periods']
optimization_start_date = config_dict['PROPHETSETTING']['optimization_start_date']
optimization_end_date = config_dict['PROPHETSETTING']['optimization_end_date']

output_bucket = config_dict["FILEPATH"]["output_bucket"]
folder_name = config_dict["FILEPATH"]["folder_name"]

base_path = config_dict["FILEPATH"]["base_path"]

boundary_df_in_path = base_path + config_dict["FILEPATH"]["boundary_df_in_path"]
daily_df_out_path = base_path + config_dict["FILEPATH"]["daily_df_out_path"]
analytical_file_path = base_path + config_dict["FILEPATH"]["analytical_file_path"]
cuts_df_in_path = base_path + config_dict["FILEPATH"]["cuts_df_in_path"]
plot_name = base_path + config_dict["FILEPATH"]["plot_name"]
constraint_file_name = base_path + config_dict["FILEPATH"]["constraint_file_name"]
breakdown_ls = [config_dict['CLIENTINFO'][i] for i in [f'breakdown{i}' for i in range(1,5)] if config_dict['CLIENTINFO'][i] != None]

small_market_str = ''
pre_forecast_period_budget = float(config_dict['CLIENTINFO']['pre_forecast_period_budget'])
client_budget = float(config_dict['CLIENTINFO']['client_budget'])

save_date = config_dict['CLIENTINFO']['save_date']

# %% [markdown]
# # Read data

# %% [markdown]
# Read the cuts df, hyper parameter table

# %%
bdDf = pd.read_csv(base_path+'New_Cuts_df.csv',index_col = False) # read the new_cuts_df.csv file 
cuts_df = bdDf
cuts_df.columns
# Out:
# Index(['market', 'account_type', 'funnel', 'periods_for_acc_cal',
#        'changepoint_prior_scale', 'seasonality_prior_scale',
#        'holidays_prior_scale', 'seasonality_mode', 'input_mode',
#        'weekday_or_weekend', 'include_holiday', 'covid_year_exclude',
#        'covid_year_dummy', 'anomaly_2021', 'generic_cost_split',
#        'competitor_cost_split', 'new_confirmed', 'power', 'growth', 'periods',
#        'cutoff_month'],
#       dtype='object')

# %%
# create a variable with the name of the pickle file
if 'market' in cuts_df.columns and 'account_type' in cuts_df.columns and 'funnel' in cuts_df.columns:
    cuts_df['forecaster_name_list'] = cuts_df['market'] + ' ' + cuts_df['account_type'] + ' ' + cuts_df['funnel'] + '.pkl'
    cuts_df['periods'] = periods  # create the variable with the number of periods to forecast
else:
    missing_columns = [col for col in ['market', 'account_type', 'funnel'] if col not in cuts_df.columns]
    print(f"Error: missin_columns: {missing_columns}")

# %% [markdown]
# get the list od pickle files

# %%
# get model list
forecasters_array = cuts_df.forecaster_name_list
forecasters_array
# Out:
# 0        Canada - Brand.pkl
# 1    Canada - Non_Brand.pkl
# Name: forecaster_name_list, dtype: object

# %%
cuts_df
# Out:
#    market account_type     funnel  periods_for_acc_cal  \
# 0  Canada            -      Brand                  183
# 1  Canada            -  Non_Brand                  183
#
#    changepoint_prior_scale  seasonality_prior_scale  holidays_prior_scale  \
# 0                    0.001                     10.0                   0.1
# 1                    0.001                      1.0                   1.0
#
#   seasonality_mode      input_mode weekday_or_weekend  ... covid_year_dummy  \
# 0         additive  multiplicative           additive  ...               na
# 1         additive  multiplicative     multiplicative  ...               na
#
#   anomaly_2021 generic_cost_split competitor_cost_split new_confirmed power  \
# 0           na                 na                    na            na    na
# 1           na                 na                    na            na    na
#
#      growth periods cutoff_month    forecaster_name_list
# 0  logistic   251.0   2024-04-25      Canada - Brand.pkl
# 1    linear   251.0   2024-04-25  Canada - Non_Brand.pkl
#
# [2 rows x 22 columns]

# %% [markdown]
# import the analytical file

# %%
# Get analytical file
analytical_file = pd.read_csv(analytical_file_path)# read the analytical file .csv 
analytical_file['ds'] = pd.to_datetime(analytical_file['ds']) # ensure the date variable is in the correct datetime type
analytical_file_check_version = analytical_file.copy() # generate a copy 
analytical_file_check_version.columns
# Out:
# Index(['region', 'market', 'account_type', 'funnel', 'ds', 'X',
#        'weekday_or_weekend', 'AOV', 'ROAS', 'floor', 'cap', 'Month', 'Year',
#        'Canada_-_Brand_Apr_2024', 'Canada_-_Brand_Aug_2024',
#        'Canada_-_Brand_Dec_2024', 'Canada_-_Brand_Jul_2024',
#        'Canada_-_Brand_Jun_2024', 'Canada_-_Brand_May_2024',
#        'Canada_-_Brand_Nov_2024', 'Canada_-_Brand_Oct_2024',
#        'Canada_-_Brand_Sep_2024', 'Canada_-_Non_Brand_Apr_2024',
#        'Canada_-_Non_Brand_Aug_2024', 'Canada_-_Non_Brand_Dec_2024',
#        'Canada_-_Non_Brand_Jul_2024', 'Canada_-_Non_Brand_Jun_2024',
#        'Canada_-_Non_Brand_May_2024', 'Canada_-_Non_Brand_Nov_2024',
#        'Canada_-_Non_Brand_Oct_2024', 'Canada_-_Non_Brand_Sep_2024'],
#       dtype='object')

# %% [markdown]
# import the constraint file

# %%
# Get constrain file
constraint_file = pd.read_csv(constraint_file_name) # read the constraint file .csv
constraint_file['init'] = constraint_file[['MinWeight', 'MaxWeight']].mean(axis = 1) #create a variable with the initial weights the mean between the min weight and the max weight
constraint_file.columns
# Out:
# Index(['market', 'account_type', 'funnel', 'Month', 'Year', 'variable_splits',
#        'Constrain_Variable_Name', 'periods_for_acc_cal',
#        'changepoint_prior_scale', 'seasonality_prior_scale',
#        'holidays_prior_scale', 'seasonality_mode', 'input_mode',
#        'weekday_or_weekend', 'include_holiday', 'covid_year_exclude',
#        'covid_year_dummy', 'anomaly_2021', 'generic_cost_split',
#        'competitor_cost_split', 'new_confirmed', 'power', 'growth', 'periods',
#        'cutoff_month', 'MinWeight', 'MaxWeight', 'init'],
#       dtype='object')

# %% [markdown]
# # PSO Function

# %% [markdown]
# Initialize the SavantPSO class function with the cuts, analytical and constraint file, also include the config dict

# %%
resultPSO = SavantPSO(cuts_df, analytical_file, constraint_file, config_dict)

# %% [markdown]
# Set the PSO hyper parameters

# %%
itNum = 150 #entre 100 a 150 cuando se tiene mas iteraciones
n_particles = 0 #asi dentro de la columna me calcula el número de particulas optima
options = {'c1': 0.20255337412386598,
 'c2': 0.034812002156869526,
 'w': 0.8707709059066462}

# %% [markdown]
# optimize the budget allocation setting optimized input weights that maximize conversion quantity. <br>
#     run_pso method of SavantPSO class function, with PSO hyper parameters

# %%
result = resultPSO.run_pso(options, n_particles=n_particles, itNum = itNum)
# Out:
# 2024-05-21 18:29:59,846 - pyswarms.single.global_best - INFO - Optimize for 150 iters with {'c1': 0.20255337412386598, 'c2': 0.034812002156869526, 'w': 0.8707709059066462}
# /home/jupyter/GroupM_US_Offshore_Hub_Savant/All Regions/ca/1 June Update/Input Weight History 05.21.2024.csv
# pyswarms.single.global_best:   0%|          |0/150
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  435864.0 difference between planned and forecast X:  0.0
# Min date in analytical file 2024-04-25 00:00:00, max date in analytical file 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# yhat: -154322.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  435864.0 difference between planned and forecast X:  0.0
# Min date in analytical file 2024-04-25 00:00:00, max date in analytical file 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# yhat: -154322.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  435864.0 difference between planned and forecast X:  0.0
# Min date in analytical file 2024-04-25 00:00:00, max date in analytical file 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# yhat: -154322.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  435864.0 difference between planned and forecast X:  0.0
# Min date in analytical file 2024-04-25 00:00:00, max date in analytical file 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# yhat: -154322.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  435864.0 difference between planned and forecast X:  0.0
# Min date in analytical file 2024-04-25 00:00:00, max date in analytical file 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# yhat: -154322.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  435864.0 difference between planned and forecast X:  0.0
# Min date in analytical file 2024-04-25 00:00:00, max date in analytical file 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# yhat: -154322.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  435864.0 difference between planned and forecast X:  0.0
# Min date in analytical file 2024-04-25 00:00:00, max date in analytical file 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# yhat: -154322.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  435864.0 difference between planned and forecast X:  0.0
# Min date in analytical file 2024-04-25 00:00:00, max date in analytical file 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# yhat: -154322.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  435864.0 difference between planned and forecast X:  0.0
# Min date in analytical file 2024-04-25 00:00:00, max date in analytical file 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# yhat: -154322.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  435864.0 difference between planned and forecast X:  0.0
# Min date in analytical file 2024-04-25 00:00:00, max date in analytical file 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# yhat: -154322.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  435864.0 difference between planned and forecast X:  0.0
# Min date in analytical file 2024-04-25 00:00:00, max date in analytical file 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# yhat: -154322.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  435864.0 difference between planned and forecast X:  0.0
# Min date in analytical file 2024-04-25 00:00:00, max date in analytical file 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# yhat: -154322.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  435864.0 difference between planned and forecast X:  0.0
# Min date in analytical file 2024-04-25 00:00:00, max date in analytical file 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# yhat: -154322.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  435864.0 difference between planned and forecast X:  0.0
# Min date in analytical file 2024-04-25 00:00:00, max date in analytical file 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# yhat: -154322.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  435864.0 difference between planned and forecast X:  0.0
# Min date in analytical file 2024-04-25 00:00:00, max date in analytical file 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# yhat: -154322.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  435864.0 difference between planned and forecast X:  0.0
# Min date in analytical file 2024-04-25 00:00:00, max date in analytical file 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# yhat: -154322.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  435864.0 difference between planned and forecast X:  0.0
# Min date in analytical file 2024-04-25 00:00:00, max date in analytical file 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# yhat: -154322.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  435864.0 difference between planned and forecast X:  0.0
# Min date in analytical file 2024-04-25 00:00:00, max date in analytical file 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# pyswarms.single.global_best:   1%|          |1/150, best_cost=-1.54e+5
# yhat: -154322.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  435865.0 difference between planned and forecast X:  -0.0
# Min date in analytical file 2024-04-25 00:00:00, max date in analytical file 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# yhat: -153027.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  435865.0 difference between planned and forecast X:  -0.0
# Min date in analytical file 2024-04-25 00:00:00, max date in analytical file 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# yhat: -152664.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  435864.0 difference between planned and forecast X:  0.0
# Min date in analytical file 2024-04-25 00:00:00, max date in analytical file 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# yhat: -153564.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  435865.0 difference between planned and forecast X:  -0.0
# Min date in analytical file 2024-04-25 00:00:00, max date in analytical file 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# yhat: -153957.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  435865.0 difference between planned and forecast X:  -0.0
# Min date in analytical file 2024-04-25 00:00:00, max date in analytical file 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# yhat: -154038.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  435864.0 difference between planned and forecast X:  0.0
# Min date in analytical file 2024-04-25 00:00:00, max date in analytical file 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# yhat: -154064.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  435864.0 difference between planned and forecast X:  0.0
# Min date in analytical file 2024-04-25 00:00:00, max date in analytical file 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# yhat: -154923.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  435865.0 difference between planned and forecast X:  -0.0
# Min date in analytical file 2024-04-25 00:00:00, max date in analytical file 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# yhat: -153895.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  435864.0 difference between planned and forecast X:  0.0
# Min date in analytical file 2024-04-25 00:00:00, max date in analytical file 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# yhat: -154418.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  435864.0 difference between planned and forecast X:  0.0
# Min date in analytical file 2024-04-25 00:00:00, max date in analytical file 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# yhat: -153746.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  435864.0 difference between planned and forecast X:  0.0
# Min date in analytical file 2024-04-25 00:00:00, max date in analytical file 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# yhat: -153867.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  435864.0 difference between planned and forecast X:  0.0
# Min date in analytical file 2024-04-25 00:00:00, max date in analytical file 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# yhat: -154250.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  435864.0 difference between planned and forecast X:  0.0
# Min date in analytical file 2024-04-25 00:00:00, max date in analytical file 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# yhat: -154939.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  435864.0 difference between planned and forecast X:  0.0
# Min date in analytical file 2024-04-25 00:00:00, max date in analytical file 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# yhat: -153295.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  435865.0 difference between planned and forecast X:  -0.0
# Min date in analytical file 2024-04-25 00:00:00, max date in analytical file 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# yhat: -154832.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  435864.0 difference between planned and forecast X:  0.0
# Min date in analytical file 2024-04-25 00:00:00, max date in analytical file 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# yhat: -153732.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  435865.0 difference between planned and forecast X:  -0.0
# Min date in analytical file 2024-04-25 00:00:00, max date in analytical file 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# yhat: -154176.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  435865.0 difference between planned and forecast X:  -0.0
# Min date in analytical file 2024-04-25 00:00:00, max date in analytical file 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# pyswarms.single.global_best:   1%|▏         |2/150, best_cost=-1.55e+5
# yhat: -152787.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  435864.0 difference between planned and forecast X:  0.0
# Min date in analytical file 2024-04-25 00:00:00, max date in analytical file 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# yhat: -153888.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  435864.0 difference between planned and forecast X:  0.0
# Min date in analytical file 2024-04-25 00:00:00, max date in analytical file 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# yhat: -153829.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  435864.0 difference between planned and forecast X:  0.0
# Min date in analytical file 2024-04-25 00:00:00, max date in analytical file 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# yhat: -154657.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  435864.0 difference between planned and forecast X:  0.0
# Min date in analytical file 2024-04-25 00:00:00, max date in analytical file 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# yhat: -152789.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  435864.0 difference between planned and forecast X:  0.0
# Min date in analytical file 2024-04-25 00:00:00, max date in analytical file 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# yhat: -152993.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  435864.0 difference between planned and forecast X:  0.0
# Min date in analytical file 2024-04-25 00:00:00, max date in analytical file 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# yhat: -153423.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  435864.0 difference between planned and forecast X:  0.0
# Min date in analytical file 2024-04-25 00:00:00, max date in analytical file 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# yhat: -154784.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  435864.0 difference between planned and forecast X:  0.0
# Min date in analytical file 2024-04-25 00:00:00, max date in analytical file 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# yhat: -153075.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  435864.0 difference between planned and forecast X:  0.0
# Min date in analytical file 2024-04-25 00:00:00, max date in analytical file 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# yhat: -154102.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  435864.0 difference between planned and forecast X:  0.0
# Min date in analytical file 2024-04-25 00:00:00, max date in analytical file 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# yhat: -153883.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  435864.0 difference between planned and forecast X:  0.0
# Min date in analytical file 2024-04-25 00:00:00, max date in analytical file 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# yhat: -154781.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  435865.0 difference between planned and forecast X:  -0.0
# Min date in analytical file 2024-04-25 00:00:00, max date in analytical file 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# Min date in future_ 2017-08-10 00:00:00, max date in future_ 2024-04-25 00:00:00
# Min date in future 2017-08-10 00:00:00, max date in future 2024-12-31 00:00:00
# pyswarms.single.global_best:   1%|▏         |2/150, best_cost=-1.55e+5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 result = resultPSO.run_pso(options, n_particles=n_particles, itNum = itNum)
#
# File ~/GroupM_US_Offshore_Hub_Savant/All Regions/repo/Optimization.py:381, in run_pso(self, options, init_pos, n_particles, itNum)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File /opt/conda/lib/python3.10/site-packages/pyswarms/single/global_best.py:209, in GlobalBestPSO.optimize(self, objective_func, iters, n_processes, verbose, **kwargs)
#     205 ftol_history = deque(maxlen=self.ftol_iter)
#     206 for i in self.rep.pbar(iters, self.name) if verbose else range(iters):
#     207     # Compute cost for current position and personal best
#     208     # fmt: off
# --> 209     self.swarm.current_cost = compute_objective_function(self.swarm, objective_func, pool=pool, **kwargs)
#     210     self.swarm.pbest_pos, self.swarm.pbest_cost = compute_pbest(self.swarm)
#     211     # Set best_cost_yet_found for ftol
#
# File /opt/conda/lib/python3.10/site-packages/pyswarms/backend/operators.py:239, in compute_objective_function(swarm, objective_func, pool, **kwargs)
#     214 """Evaluate particles using the objective function
#     215
#     216 This method evaluates each particle in the swarm according to the objective
#    (...)
#     236     Cost-matrix for the given swarm
#     237 """
#     238 if pool is None:
# --> 239     return objective_func(swarm.position, **kwargs)
#     240 else:
#     241     results = pool.map(
#     242         partial(objective_func, **kwargs),
#     243         np.array_split(swarm.position, pool._processes),
#     244     )
#
# File ~/GroupM_US_Offshore_Hub_Savant/All Regions/repo/Optimization.py:73, in SavantPSO._objective_funtion_wrap(self, x)
#      60 """
#      61 Function used to generate the maximized output based on given inputWeights across particles
#      62
#    (...)
#      70     numpy.ndarray for maximized output across particles
#      71 """
#      72 n_particles = x.shape[0]
# ---> 73 j = [self._objective_funtion(x[i]) for i in range(n_particles)]
#      74 return np.array(j)
#
# File ~/GroupM_US_Offshore_Hub_Savant/All Regions/repo/Optimization.py:73, in <listcomp>(.0)
#      60 """
#      61 Function used to generate the maximized output based on given inputWeights across particles
#      62
#    (...)
#      70     numpy.ndarray for maximized output across particles
#      71 """
#      72 n_particles = x.shape[0]
# ---> 73 j = [self._objective_funtion(x[i]) for i in range(n_particles)]
#      74 return np.array(j)
#
# File ~/GroupM_US_Offshore_Hub_Savant/All Regions/repo/Optimization.py:136, in SavantPSO._objective_funtion(self, inputWeights)
#     122 """
#     123 Function used to generate the maximized output based on given inputWeights
#     124
#    (...)
#     132     numpy.float64 for maximized output
#     133 """
#     134 variable_list_before, variable_list_latest = self._get_before_after_variable()
# --> 136 daily_simulated_forecast, updated_weights = self._predict(inputWeights, variable_list_before, variable_list_latest)
#     138 # check if any yhat equals nan
#     139 error_idx = daily_simulated_forecast.index[daily_simulated_forecast['yhat'].isna()]
#
# File ~/GroupM_US_Offshore_Hub_Savant/All Regions/repo/Optimization.py:239, in SavantPSO._predict(self, inputWeights, variable_list_before, variable_list_latest)
#     237 for i in self.cuts_df.itertuples():
#     238     forecast = self._forecast_fn(i, analytical_file_temp)
# --> 239     forecasts_df = pd.concat([forecasts_df, forecast], ignore_index=True)
#     242 # put forecasted y to daily_simulated_forecast
#     243 daily_simulated_forecast = daily_simulated_forecast.merge(forecasts_df[['market', 'account_type', 'funnel', 'ds', 'yhat']], how = 'left', on = ['market', 'account_type', 'funnel', 'ds'])
#
# File ~/GroupM_US_Offshore_Hub_Savant/All Regions/repo/Optimization.py:112, in SavantPSO._forecast_fn(self, i, analytical_file)
#     108 spend_df_for_forecast['ds'] = pd.to_datetime(spend_df_for_forecast.ds)
#     110 future = MakeFuture(unpickled_model, training_dataset, i, i.periods, spend_df_for_forecast)
# --> 112 forecast = unpickled_model.predict(future)
#     113 remove_negs(forecast)
#     114 round_forecast(forecast)
#
# File /opt/conda/lib/python3.10/site-packages/prophet/forecaster.py:1275, in Prophet.predict(self, df, vectorized)
#    1273 seasonal_components = self.predict_seasonal_components(df)
#    1274 if self.uncertainty_samples:
# -> 1275     intervals = self.predict_uncertainty(df, vectorized)
#    1276 else:
#    1277     intervals = None
#
# File /opt/conda/lib/python3.10/site-packages/prophet/forecaster.py:1449, in Prophet.predict_uncertainty(self, df, vectorized)
#    1446 for key in ['yhat', 'trend']:
#    1447     series['{}_lower'.format(key)] = self.percentile(
#    1448         sim_values[key], lower_p, axis=1)
# -> 1449     series['{}_upper'.format(key)] = self.percentile(
#    1450         sim_values[key], upper_p, axis=1)
#    1452 return pd.DataFrame(series)
#
# File /opt/conda/lib/python3.10/site-packages/prophet/forecaster.py:1828, in Prophet.percentile(self, a, *args, **kwargs)
#    1820 """
#    1821 We rely on np.nanpercentile in the rare instances where there
#    1822 are a small number of bad samples with MCMC that contain NaNs.
#    (...)
#    1825 https://github.com/facebook/prophet/issues/1310 for more details.
#    1826 """
#    1827 fn = np.nanpercentile if np.isnan(a).any() else np.percentile
# -> 1828 return fn(a, *args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/numpy/lib/function_base.py:4283, in percentile(a, q, axis, out, overwrite_input, method, keepdims, interpolation)
#    4281 if not _quantile_is_valid(q):
#    4282     raise ValueError("Percentiles must be in the range [0, 100]")
# -> 4283 return _quantile_unchecked(
#    4284     a, q, axis, out, overwrite_input, method, keepdims)
#
# File /opt/conda/lib/python3.10/site-packages/numpy/lib/function_base.py:4555, in _quantile_unchecked(a, q, axis, out, overwrite_input, method, keepdims)
#    4547 def _quantile_unchecked(a,
#    4548                         q,
#    4549                         axis=None,
#    (...)
#    4552                         method="linear",
#    4553                         keepdims=False):
#    4554     """Assumes that q is in [0, 1], and is an ndarray"""
# -> 4555     return _ureduce(a,
#    4556                     func=_quantile_ureduce_func,
#    4557                     q=q,
#    4558                     keepdims=keepdims,
#    4559                     axis=axis,
#    4560                     out=out,
#    4561                     overwrite_input=overwrite_input,
#    4562                     method=method)
#
# File /opt/conda/lib/python3.10/site-packages/numpy/lib/function_base.py:3823, in _ureduce(a, func, keepdims, **kwargs)
#    3820             index_out = (0, ) * nd
#    3821             kwargs['out'] = out[(Ellipsis, ) + index_out]
# -> 3823 r = func(a, **kwargs)
#    3825 if out is not None:
#    3826     return out
#
# File /opt/conda/lib/python3.10/site-packages/numpy/lib/function_base.py:4721, in _quantile_ureduce_func(a, q, axis, out, overwrite_input, method)
#    4719         arr = a.flatten()
#    4720     else:
# -> 4721         arr = a.copy()
#    4722 result = _quantile(arr,
#    4723                    quantiles=q,
#    4724                    axis=axis,
#    4725                    method=method,
#    4726                    out=out)
#    4727 return result
#
# KeyboardInterrupt:

# %% [markdown]
# Save the PSO optimization results and plot the cost through the different iterations

# %%
resultPSO.SaveResult(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 resultPSO.SaveResult(result)
#
# NameError: name 'result' is not defined

# %% [markdown]
# #### if PSO optimization has already being run and we have some inititial input wehights

# %% [markdown]
# Read initial position input weights

# %%
pso_date = '01.21.2024' #datetime.date.today().strftime("%m.%d.%Y")# 
fileName = base_path + f'Pos Result {pso_date}.csv' 
pos_df = pd.read_csv(fileName).drop('Unnamed: 0', axis = 1) # read the pso result file to get the input weights
inputWeights =np.tile(pos_df.pos.to_numpy(), [n_particles, 1]) # create the input weights parameters
# Out:
# 2024-04-18 03:50:53,381 - pyswarms.single.global_best - INFO - Optimize for 50 iters with {'c1': 0.20255337412386598, 'c2': 0.034812002156869526, 'w': 0.8707709059066462}
# /home/jupyter/All Regions/us/test of Juan/Input Weight History 04.18.2024.csv
# pyswarms.single.global_best:   0%|          |0/50
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -627223.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -627223.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -627223.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -627223.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -627223.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -627223.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -627223.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -627223.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -627223.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -627223.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -627223.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -627223.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -627223.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -627223.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -627223.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# pyswarms.single.global_best:   2%|▏         |1/50, best_cost=-6.27e+5
# yhat: -627223.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -625920.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  -0.0
# yhat: -627965.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -625439.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -626073.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -629791.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -628388.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -626534.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -622777.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -627145.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -626098.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -625688.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  -0.0
# yhat: -631279.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -626682.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -628032.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -626303.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# pyswarms.single.global_best:   4%|▍         |2/50, best_cost=-6.31e+5
# yhat: -627154.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -626487.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -623671.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  -0.0
# yhat: -624474.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  -0.0
# yhat: -629433.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -627711.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -627581.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -630376.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -626651.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -624576.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -629479.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -628053.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -624901.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -626395.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -626077.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -626122.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# pyswarms.single.global_best:   6%|▌         |3/50, best_cost=-6.31e+5
# yhat: -630077.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  -0.0
# yhat: -629344.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -626405.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -628313.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -628924.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -624039.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -624303.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -628678.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -628536.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -627827.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -628239.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -628161.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -629285.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -628081.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -627111.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -629018.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# pyswarms.single.global_best:   8%|▊         |4/50, best_cost=-6.31e+5
# yhat: -626927.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -628829.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -626748.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -629914.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -624549.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -628274.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -627882.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -628069.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -627862.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -625404.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  -0.0
# yhat: -628253.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -630024.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -626593.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -625711.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -626542.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -627795.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# pyswarms.single.global_best:  10%|█         |5/50, best_cost=-6.31e+5
# yhat: -627154.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -630852.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -626746.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -626083.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -625418.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -629431.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -625135.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  -0.0
# yhat: -626125.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -629282.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  -0.0
# yhat: -628904.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -623480.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -629680.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -628763.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -626872.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -630010.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -624853.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# pyswarms.single.global_best:  12%|█▏        |6/50, best_cost=-6.31e+5
# yhat: -626722.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -623639.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -623052.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -627056.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -626796.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -628730.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -629904.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -625731.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -626548.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -628034.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -628390.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -630101.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -622947.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -626601.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -628068.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  -0.0
# yhat: -629414.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# pyswarms.single.global_best:  14%|█▍        |7/50, best_cost=-6.31e+5
# yhat: -629140.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -626319.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  -0.0
# yhat: -622788.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -625213.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -626104.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -626930.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  -0.0
# yhat: -628078.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -625780.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -628733.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -628204.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -628368.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -627124.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -628398.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -626923.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  -0.0
# yhat: -626920.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -624105.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# pyswarms.single.global_best:  16%|█▌        |8/50, best_cost=-6.31e+5
# yhat: -629212.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  -0.0
# yhat: -628051.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -625724.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  -0.0
# yhat: -626229.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  -0.0
# yhat: -628617.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -627350.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -629607.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -627432.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  -0.0
# yhat: -630209.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -625906.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -627671.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -624787.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -624276.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -627273.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  -0.0
# yhat: -629338.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -627473.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# pyswarms.single.global_best:  18%|█▊        |9/50, best_cost=-6.31e+5
# yhat: -627540.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -628462.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  -0.0
# yhat: -627599.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -622111.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -625669.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -623619.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  -0.0
# yhat: -624699.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -627473.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -627342.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -623673.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -625238.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -630231.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  -0.0
# yhat: -628773.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -626061.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -626485.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -626472.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# pyswarms.single.global_best:  20%|██        |10/50, best_cost=-6.31e+5
# yhat: -629989.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -626745.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -628481.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -626624.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  -0.0
# yhat: -627228.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -629770.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  -0.0
# yhat: -628150.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -627089.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -627479.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  -0.0
# yhat: -625819.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  -0.0
# yhat: -630752.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -627276.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -629912.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -626117.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -625969.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -625518.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  -0.0
# pyswarms.single.global_best:  22%|██▏       |11/50, best_cost=-6.31e+5
# yhat: -626803.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -628886.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -626028.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  -0.0
# yhat: -624266.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  -0.0
# yhat: -626573.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -630064.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -623708.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -628692.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -629434.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -628135.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -626008.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -623983.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -625376.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -628618.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -630052.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  -0.0
# yhat: -626434.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# pyswarms.single.global_best:  24%|██▍       |12/50, best_cost=-6.31e+5
# yhat: -627614.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -626408.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -625375.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -624686.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -630763.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -627553.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -627521.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -625180.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -625977.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -627847.0
# ...
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -628094.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# pyswarms.single.global_best:  92%|█████████▏|46/50, best_cost=-6.32e+5
# yhat: -628787.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -629312.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -630167.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -628323.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -626752.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -626651.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -626726.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -625380.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -627619.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  -0.0
# yhat: -626030.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -623272.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -628723.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -628240.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  -0.0
# yhat: -628773.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  -0.0
# yhat: -629235.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -625399.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# pyswarms.single.global_best:  94%|█████████▍|47/50, best_cost=-6.32e+5
# yhat: -628258.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -624890.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -624394.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -630209.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  -0.0
# yhat: -627433.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -628460.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -628031.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -625656.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -629635.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -627328.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -627617.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -626444.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -627683.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -624119.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -628220.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -624253.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# pyswarms.single.global_best:  96%|█████████▌|48/50, best_cost=-6.32e+5
# yhat: -629150.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  -0.0
# yhat: -628904.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -626296.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -627112.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -625284.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -629350.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  -0.0
# yhat: -626268.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -629234.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -628370.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -630191.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -627736.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  -0.0
# yhat: -627457.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -627610.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -627601.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  -0.0
# yhat: -630731.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -627752.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# pyswarms.single.global_best:  98%|█████████▊|49/50, best_cost=-6.32e+5
# yhat: -627822.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -630134.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -626944.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -629498.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -629088.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -624257.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -629540.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -626020.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -629959.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -625477.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -628777.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -624269.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -624887.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -627188.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -626920.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  0.0
# yhat: -624339.0
# client_budget - analytical_spend_latest_period: 0
# --------------Optimized spend isn't the same as what UPS planned.---------------
# Test 1: total X next year:  1107066.0 difference between planned and forecast X:  -0.0
# pyswarms.single.global_best: 100%|██████████|50/50, best_cost=-6.32e+5
# 2024-04-18 05:26:34,175 - pyswarms.single.global_best - INFO - Optimization finished | best cost: -631591.0, best pos: [0.94147144 1.13235445 0.90735946 1.12861693 1.0601695  1.05763392
#  1.18663699 1.14510455 0.99752745 0.80679573 1.01964194 0.86363084]
# yhat: -628250.0
# client_budget - analytical_spend_latest_period: 0
# Compute duration: 5740.795632123947

# %% [markdown]
# run_pso method of SavantPSO class function, with PSO hyper parameters and input weights as initial position

# %%
result = resultPSO.run_pso(options, n_particles=n_particles, itNum = itNum , init_pos=inputWeights)

# %% [markdown]
# if needed cave the PSO optimization results and plot the cost through the different iterations

# %%
resultPSO.SaveResult(result)
